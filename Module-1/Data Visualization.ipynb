# %% [markdown]
# Data visualization is the graphical representation of information and data.
#
# • Matplotlib: low level, provides lots of freedom
#
# pip install matplotlib
# import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
#
# Figures:
#          fig = plt.figure()
#
# Subplots:
#          plt.subplot()
#
# Matplotlib Markers:
#          plt.plot(ypoints, marker = 'o')
#
# Matplotlib Line:
#          plt.plot(ypoints, linestyle = 'dotted')
#
# Line Color:
#          plt.plot(ypoints, color = 'r')
#
# Marker Color:
#           plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
#
# Scatter Plot:
#           plt.scatter()
#
# Pie chart:
#           plt.pie()
#
# Ticks and Labels:
#           plt.tick_params(axis="x",labelsize=20,labelrotation=-45,labelcolor="black")
#
# Adding title:
#           plt.title()
#
# Adding lable:
#           plt.xlable()
#
# Adding Legend:
#           plt.legend()
#
# subplot() function:
#           plt.subplot()
#
# Histograms:
#           plt.hist()
#
# Histograms and Binning:
#           plt.hist(data,bins=30);
#
# Text and Annotations:
#            plt.annotate()
#
# Three-Dimensional Plotting in Matplotlib:
#             from mpl_toolkits import mplot3d
#
# Plotting 3-D Lines and Points:
#              ax.olot3D
#
# 3-D title:
#           ax.set_title()

# %% [markdown]
# # colors,Markers and line style

# %%
import numpy as np

# %%
x =np.array([3,5,7,8])
y =np.array([2,5,6,7])
plt.plot(x,y, marker = 'D',color='blue')

plt.show()

# %%
x =np.array([3,5,7,8])
y =np.array([2,5,6,7])
plt.plot(x,y, marker = 'D',color='blue',linestyle='dashdot')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("line plot")
plt.show()

# %%
import random as ran

students=['janvi','dhruv','aayushi','shivam','twisha']

marks=[]
for i in range(0,len(students)):
    marks.append(ran.randint(0,201))
    
plt.xlabel("students") 
#plt.xticks(rotation)
plt.ylabel("marks")
plt.title("class records")
plt.plot(students,marks,color='blue',linestyle='solid',marker='D',markerfacecolor='red',markersize=12)

# %% [markdown]
# # LinePlot

# %%
#x-axis value
x=[1,2,3]
#y-axis value
y=[3,5,2]
#plotting the point
plt.plot(x,y)
#naming the x axis
plt.xlabel('Divyesh')
#naming the y axis
plt.ylabel('Dhruv')
#giving a titl to my graph
plt.title('my first graph!')
#function to show
plt.show()

# %% [markdown]
# # polting with numpy

# %%
import numpy as np
x=np.arange(0,20,0.5)
#print(x)
y=np.sin(x)
#print(y)

#figure in matplotlib using figure()
plt.figure(figsize=(20,6))
plt.plot(x,y)
plt.show()

# %%
#plot 1:
x=np.array([0,2,3,4])
y=np.array([0,3,9,5])
plt.subplot(1,3,1)  #plt.subplot(rows,columns,plot.no.)
plt.plot(x,y)
plt.xlabel('Divyesh')
plt.ylabel('Dhruv')
plt.title('my first graph!')
#plot 2:
x=np.array([0,1,3,7])
y=np.array([0,2,4,5])

plt.subplot(1,3,2)
plt.plot(x,y)
plt.xlabel('Divyesh')
plt.ylabel('Dhruv')
plt.title('my first graph!')

#plot 3:
x=np.array([0,5,3,7])
y=np.array([0,7,4,5])

plt.subplot(1,3,3)
plt.plot(x,y)
plt.xlabel('Divyesh')
plt.ylabel('Dhruv')
plt.title('my first graph!')

plt.suptitle('name')
# Out:
# Text(0.5, 0.98, 'name')

# %%
import numpy as np
import matplotlib.pyplot as plt

ypoint=np.array([5,6,8,9])

plt.plot(ypoint,marker='o',ms=30,mec='b')
plt.show()

# %% [markdown]
# # bar plot

# %%
#importing matplotlib module
from matplotlib import pyplot as plt

#x-axis values
x=[3,5,7,9]

#y-axis values
y=[6,8,9,11]

#function to plot
plt.bar(x,y)
plt.show()

# %% [markdown]
# # scatter plot

# %%
#importing matplotlib module
from matplotlib import pyplot as plt

#x-axis values
x=[3,5,7,9,8,9,5,11,12,18]

#y-axis values
y=[6,8,9,11,15,2,5,8,9,10]

#function to plot
plt.scatter(x,y)
plt.title("scatter plot")
plt.show()

# %%
#ticks are the marker denoting data point on axes.
#importing libraries

#values of x and y axis
x=[5,8,20,15,65,25,78,21,20,10]
y=[2,25,41,20,12,20,56,15,45,20]

plt.plot(x,y,'g')
plt.xlabel('Divyesh')
plt.ylabel('Dhruv')

#here we set the size for ticks,rotation and color value

plt.tick_params(axis="x",labelsize=20,labelrotation=-45,labelcolor="black")
plt.tick_params(axis="y",labelsize=12,labelrotation=20,labelcolor="blue")
plt.show()

# %%
#Adding title and labelling the Axis in the grph 
#importing matplotlib module
from matplotlib import pyplot as plt

#x-axis values
x=[3,5,7,9,8]

#y-axis values
y=[6,8,9,11,15]

#function to plot

# %% [markdown]
# # adding ligent graph

# %%
import numpy as np
import matplotlib.pyplot as plt

#y-axis values
y1=[2,5,6,7]

#y-axis values
y2=[5,3,4,5]

#function to plot
plt.plot(y1)
plt.plot(y2)

#function add a legend
plt.legend(["blue","orange"])

plt.show()

# %% [markdown]
# # Histogram

# %%
#import module

data=np.random.normal(150,20,260)


#the hist()function will read the array produce a histogram:
#set the bin valuue 20:

plt.hist(data);
plt.show()
plt.hist(data,bins=20);
plt.show()

# %%
#import matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy as np

#draw plot as fig
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
#text annotation to the plot where it indicate maximum value of the curv
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))
#text annotation to the plot where it indicate minimum value of the curv
ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"));

# %% [markdown]
# # Adding Annotatae & legend

# %%
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt 
#you can also right

x=np.arange(0,20)
y=x^3
z=x^4

plt.plot(x,y)
plt.plot(y,z)
plt.plot(z,x)
plt.title("graph")
plt.xlabel("Time")
plt.ylabel("Distance")


#Annotataion

plt.annotate(xy=[2,1],text="first value",rotation=2)
plt.annotate(xy=[4,6],text="second value",rotation=2)
plt.annotate(xy=[8,10],text="Third value",rotation=2)

#add legend
plt.legend(["Race 1","Race 2","race 3"],loc=2)
plt.show()

# %% [markdown]
# # visualization using  numpy

# %%
x=np.arange(0,3*np.pi,0.2)
y=np.tan(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Pie chart
#
# pie chart is a circular stastical plot that can display only one series of data.
#
# the area of the chart is the total% of the given data

# %%
#import librarties

import numpy as np
import matplotlib.pyplot as plt

#Creating dataset
Branch = ['computer', 'mechnical', 'electical',
		'civil', 'chemical', 'automobile']

data = [43, 17, 30, 29, 12,20]
explode=(0.1,0,0,0.3,0,0)
# Creating chart

fig = plt.figure(figsize =(12, 7))
plt.pie(data, labels = Branch,explode=explode,autopct='%1.3f%%',shadow=True)
plt.title("Neotech Branch")


# show plot
plt.show()

# %% [markdown]
# # 3D ploting

# %%
#import mplot3D tiilkit,numpy &matplotlib

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d #3D toolkit lib

# %%
fig=plt.figure()
# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining all 3 axes
z = np.linspace(0, 3, 200)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

#3D plotting
ax.plot3D(x, y, z, 'red')
ax.set_title('3D ploting')
plt.show()

# %% [markdown]
# # Saving the chart

# %%
import numpy as np
import matplotlib.pyplot as plt

#Creating dataset
Branch = ['computer', 'mechnical', 'electical',
		'civil', 'chemical', 'automobile']

data = [43, 17, 30, 29, 12,20]
explode=(0.1,0,0,0.3,0,0)
# Creating chart

fig = plt.figure(figsize =(12, 7))
plt.pie(data, labels = Branch,explode=explode,autopct='%1.3f%%',shadow=True)
plt.title("Neotech Branch")


# show plot


plt.savefig("class.pdf",dpi=200)
plt.show()
